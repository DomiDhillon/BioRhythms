# %%
# you don't need all of them here - they are imported into modules od cs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from cs.csv2pd import *
from cs.plot_DataFilter import *
from cs.morletTransform import *
from cs.plot_hists import *

# %%
path='.../data'
rat10=csv2pd(timestamp_col=0,path=path,fileName='rat10.csv') #csv2pd uses interpolation for missing point

# %%
rat10.head()
# Out:
#                      Spikes/h  Temp_(Mean,_3600s)  Activity_(Mean,_3600s)
# 2020-07-08 14:00:00     241.0               37.48                    0.07
# 2020-07-08 15:00:00     213.0               37.15                    0.05
# 2020-07-08 16:00:00     381.0               37.17                    0.07
# 2020-07-08 17:00:00     307.0               37.14                    0.04
# 2020-07-08 18:00:00     331.0               37.15                    0.07

# %%
color_hist(rat10,0)
color_hist(rat10,2)

# %%
title = "Hourly count of interictal spikes"
plot_DataFilter(rat10,0,cutoff=1/5, title=title)
plot_spect(rat10,0,scale_max=600, title=title)
